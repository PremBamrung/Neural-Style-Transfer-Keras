# %%
import datetime
print(datetime.datetime.now().time())
# Out:
# 08:54:08.893810

# %%
# Out:
# Using TensorFlow backend.

# %%
from matplotlib import pyplot as plt
import cv2

image = cv2.imread("/content/Shiba.jpg")
image=cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
plt.imshow(image)
plt.xticks([]),plt.yticks([])
plt.show()

# %%
image = cv2.imread("/content/La_nuit_étoilée_Van_Gogh.jpg")
image=cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
plt.imshow(image)
plt.xticks([]),plt.yticks([])
plt.show()

# %%
import time

start = time.time()
# !python neural_style_transfer.py /content/Shiba.jpg /content/La_nuit_étoilée_Van_Gogh.jpg my_result --iter 600
end = time.time()
print(end - start)
# Out:
# Using TensorFlow backend.
# WARNING: Logging before flag parsing goes to stderr.
# W0619 08:55:44.833483 139697304749952 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0619 08:55:44.835682 139697304749952 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0619 08:55:44.836316 139697304749952 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# ...

# %%
print("Hello")
from google.colab import files
#files.download('file.txt')
# Out:
# Hello

# %%
# !mkdir Result
# !bash -c 'mv cat.{0..499}.jpg /content/train'
# !zip -r /content/file.zip /content/Result
